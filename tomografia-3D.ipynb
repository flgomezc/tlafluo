# %%
# %pylab inline
from PIL import Image
import scipy.ndimage
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
L = 3.0 # cm
l = 104 # px

def y_prim(n):
    return (n*2*L/l - L)
def x_prim(m):
    return (m*2*L/l - L)

def M(x): 
    return int((l/(2*L))*(x+L))
def N(y):
    return int((l/(2*L))*(y+L))

def X(xprim, yprim, theta):
    return xprim*cos(theta) - yprim*sin(theta)
def Y(xprim, yprim, theta):
    return xprim*sin(theta) + yprim*cos(theta)

# %%
h = 9

Muestra = zeros([l,l,h])
k=0
for z in linspace(0,120,h):
    A = range(0,20)
    for filenumber in A:
        IM = Image.open('data/%i.tif' %filenumber)
        #figure()
        #imshow(IM)
        IMarray = array(IM)
        IMarray = IMarray /255
        I = (IMarray[z]-1)/255.0

        M_prim = zeros([l,l])
        theta = filenumber*pi/20
        for i in range(l):
            for j in range(l):
                AA = X(x_prim(i),y_prim(j),theta)
                BB = Y(x_prim(i),y_prim(j),theta)

                if (0<=M(AA))&(M(AA)<l):
                    if (0<=N(BB))&(N(BB)<l):
                        M_prim[M(AA),N(BB)]+= I[j]
        #figure(figsize=(5,5))
        #imshow(M_prim)

        M2_prim = scipy.ndimage.filters.gaussian_filter(M_prim, 1.0)

        M2_prim[where(M2_prim>0.5)]=1.0
        M2_prim[where(M2_prim<0.5)]=0.0

        #imshow(M2_prim)

        Muestra[:,:,k] += M2_prim
        
    figure(figsize=(5,5))   
    imshow(Muestra[:,:,k])
    k+=1

# %%
Muestra2 = zeros([l,l,h])

for i in range (l):
    for j in range (l):
        for k in range(h):
            Muestra2[i,j,k] = Muestra[i,j,k]

# %%
Muestra2[where(Muestra2<18)]=0

# %%
for k in range(h):
    figure()
    imshow(Muestra2[:,:,k])
    figure()
    imshow(Muestra[:,:,k])
    print k
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
f = zeros([l,l])
f[:,:] = Muestra[:,:,h-1]

F = fft.fft2(f)

#for i in range (l):
#    for j in range (l):
#        F *= ( (1.0/(i+1))**(2) + (1.0/(j+1))**(2) )**0.5

f = abs(fft.ifft2(F))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-43-624a27dfdf52> in <module>()
#       2 f[:,:] = Muestra[:,:,h-1]
#       3
# ----> 4 freq = fft.fftfreq(f)
#       5 print freq
#       6
#
# /usr/lib/pymodules/python2.7/numpy/fft/helper.pyc in fftfreq(n, d)
#     151
#     152     """
# --> 153     assert isinstance(n,types.IntType) or isinstance(n, integer)
#     154     val = 1.0/(n*d)
#     155     results = empty(n, int)
#
# AssertionError:

# %%
imshow(f)

# %%
F.shape
# Out:
# (104, 104)
